# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Часть-1-Приоритизация-гипотез-фреймворками-ICE-&amp;-RICE" data-toc-modified-id="Часть-1-Приоритизация-гипотез-фреймворками-ICE-&amp;-RICE-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Часть 1 Приоритизация гипотез фреймворками ICE &amp; RICE</a></span></li><li><span><a href="#Часть-2-Анализ-A/B-теста" data-toc-modified-id="Часть-2-Анализ-A/B-теста-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Часть 2 Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-предобработка-данных" data-toc-modified-id="Загрузка-и-предобработка-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Загрузка и предобработка данных</a></span></li><li><span><a href="#График-кумулятивной-выручки-по-группам" data-toc-modified-id="График-кумулятивной-выручки-по-группам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>График кумулятивной выручки по группам</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#График-кумулятивной-конверсии-по-группам" data-toc-modified-id="График-кумулятивной-конверсии-по-группам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>График кумулятивной конверсии по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>График относительного изменения кумулятивной конверсии группы B к группе A.</a></span></li><li><span><a href="#Точечный-график-количества-заказов-по-пользователям" data-toc-modified-id="Точечный-график-количества-заказов-по-пользователям-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Точечный график количества заказов по пользователям</a></span></li><li><span><a href="#95-й-и-99-й-перцентили-количества-заказов-на-пользователя" data-toc-modified-id="95-й-и-99-й-перцентили-количества-заказов-на-пользователя-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>95-й и 99-й перцентили количества заказов на пользователя</a></span></li><li><span><a href="#Точечный-график-стоимостей-заказов" data-toc-modified-id="Точечный-график-стоимостей-заказов-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Точечный график стоимостей заказов</a></span></li><li><span><a href="#95-й-и-99-й-перцентили-стоимости-заказов" data-toc-modified-id="95-й-и-99-й-перцентили-стоимости-заказов-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>95-й и 99-й перцентили стоимости заказов</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным" data-toc-modified-id="Статистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Статистическая значимость различий в конверсии между группами по «сырым» данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Статистическая значимость различий в среднем чеке заказа между группами по «сырым» данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным" data-toc-modified-id="Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Статистическая значимость различий в конверсии между группами по «очищенным» данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Статистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Статистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li></ul></li><li><span><a href="#Вывод,-результаты-A/B-теста" data-toc-modified-id="Вывод,-результаты-A/B-теста-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод, результаты A/B теста</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Принятие решений в бизнесе на основе данных

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Аналитиком крупного интернет-магазина вместе с отделом маркетинга был подготовлен список гипотез для увеличения выручки. В датафрейме с гипотезами указаны поарметры Reach, Impact, Confidence, Effort.
#
# Для проведения и анализа результатов A/B-теста аналитику предоставлены датафреймы о совершенных заказах и покупателях.
#
# Задача анатитика:
# - приоритизировать гипотезы известными фреймворками;
# - провести A/B-тест и проанализировать его результаты.

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import math as mt
from math import factorial

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# ## Часть 1 Приоритизация гипотез фреймворками ICE & RICE

# %%
hypothesis = pd.read_csv('/datasets/hypothesis.csv')
hypothesis
# Out:
#                                           Hypothesis  Reach  Impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    Confidence  Efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
# 5           2        3
# 6           8        3
# 7           8        5
# 8           9        5

# %%
hypothesis['Hypothesis'].unique()
# Out:
# array(['Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей',
#        'Запустить собственную службу доставки, что сократит срок доставки заказов',
#        'Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа',
#        'Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар',
#        'Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей',
#        'Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов',
#        'Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию',
#        'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок',
#        'Запустить акцию, дающую скидку на товар в день рождения'],
#       dtype=object)

# %%
pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 150
print(hypothesis['Hypothesis'])
# Out:
# 0              Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                       Запустить собственную службу доставки, что сократит срок доставки заказов
# 2    Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3             Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                                Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                        Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6            Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 7                Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# ...

# %%
#перевела названия колонок в нижний регистр для удобства
hypothesis.columns = hypothesis.columns.str.lower()
hypothesis.head(2)
# Out:
#                                                                                            hypothesis  \
# 0  Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                           Запустить собственную службу доставки, что сократит срок доставки заказов
#
#    reach  impact  confidence  efforts
# 0      3      10           8        6
# 1      2       5           4       10

# %%
#применяю фреймворк ICE для приоритизации гипотез
hypothesis['ICE'] = ((hypothesis['impact'] * hypothesis['confidence'] ) / hypothesis['efforts']).round(3)
hypothesis.sort_values(by = 'ICE', ascending = False)
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %%
#применяю фреймворк RICE для приоритизации гипотез
hypothesis['RICE'] = ((hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] ) / hypothesis['efforts'])
hypothesis.sort_values(by = 'RICE', ascending = False)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# При применении фреймворка <b>ICE</b> приоритетными были следующие гипотезы: <br>
# Наиболее приоритетная - <i>"Запустить акцию, дающую скидку на товар в день рождения"</i>, <br>
# Далее: <i>"Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей"</i> и <i>"Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок"</i><br>
#
# При применении фреймворка <b>RICE</b> приоритетной была выявлена гипотезы <i>"Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок"</i>, <br>после нее следуют: <i>"Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа"</i>, <i>"Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей"</i>, <i>"Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию"</i>
#
# Приоритизация гипотез вышла разной, потому что фреймворк <b>RICE</b> использует дополнительный параметр <b>Reach</b>, который отражает охват гипотезы в количестве пользователей, переведенных в баллы десятибалльной шкалы, поэтому на первое место вышла гипотеза <i>"Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок"</i>, у которой параметр Reach максимальный - 10.
#
# При применении обоих фреймворков приоритизации гипотез, в оба топа попали гипотезы <i>"Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей"</i> и <i>"Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок"</i>, на них бы я и обратила внимание в первую очередь.

# %% [markdown]
# ## Часть 2 Анализ A/B-теста

# %% [markdown]
# ### Загрузка и предобработка данных

# %% [markdown]
# Загружаю данные, провряю типы данных, названи столбцов, пропуски и дубликаты

# %%
orders = pd.read_csv('/datasets/orders.csv')
orders
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]

# %%
orders.isna().sum()
# Out:
# transactionId    0
# visitorId        0
# date             0
# revenue          0
# group            0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
# transactionId    1197 non-null int64
# visitorId        1197 non-null int64
# date             1197 non-null object
# revenue          1197 non-null int64
# group            1197 non-null object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
# transactionId    1197 non-null int64
# visitorId        1197 non-null int64
# date             1197 non-null datetime64[ns]
# revenue          1197 non-null int64
# group            1197 non-null object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB

# %%
visitors = pd.read_csv('/datasets/visitors.csv')
visitors
# Out:
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718
#
# [62 rows x 3 columns]

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
# date        62 non-null object
# group       62 non-null object
# visitors    62 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
# date        62 non-null datetime64[ns]
# group       62 non-null object
# visitors    62 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
visitors.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %%
visitors.duplicated().sum()
# Out:
# 0

# %%
print('Число уникальных пользователей всего:', orders['visitorId'].nunique())
# Out:
# Число уникальных пользователей всего: 1031

# %%
print('Распределение уникальных пользователей по группам:', orders.groupby('group')['visitorId'].nunique())
# Out:
# Распределение уникальных пользователей по группам: group
# A    503
# B    586
# Name: visitorId, dtype: int64

# %%
print('Сумма уникальных пользователей в группе A и B:', orders.query('group == "A"')['visitorId'].nunique() + orders.query('group == "B"')['visitorId'].nunique())
# Out:
# Сумма уникальных пользователей в группе A и B: 1089

# %%
visitors_in_groups = orders[['visitorId','group']].drop_duplicates()
visitors_in_groups
# Out:
#        visitorId group
# 0     3312258926     B
# 1     3642806036     B
# 2     4069496402     A
# 3     1196621759     B
# 4     2322279887     B
# ...          ...   ...
# 1191   608641596     B
# 1192  3733762160     B
# 1193   370388673     A
# 1194   573423106     A
# 1196  2108080724     B
#
# [1089 rows x 2 columns]

# %%
visitors_in_groups['visitorId'].duplicated().sum()
# Out:
# 58

# %%
visitors_in_groups[visitors_in_groups.duplicated(['visitorId'], keep=False)].head(10)
# Out:
#      visitorId group
# 2   4069496402     A
# 20   963407295     B
# 23   351125977     B
# 24  3234906277     B
# 26   199603092     A
# 27   237748145     B
# 29  3803269165     A
# 32  2038680547     B
# 33  2378935119     A
# 41   237748145     A

# %% [markdown]
# Вычислила 58 пользователей, которые по каким-то причинам попали в два теста одновременно.
#
# Среди них могут быть те, кто сами тест и проводят и перекидывают себя между группами, либо возникла проблема при разделении аудитории на тесты.
#     Как я понимаю, просто дропнуть их нельзя, тк это может повлечь за собой некорректность дальнейшего анализа про построении гипотез
#
# Данные загружены, проверены и подготовлены к дальнейшему анализу

# %% [markdown]
# ### График кумулятивной выручки по группам

# %%
#создаю датафрейм с уникальными парами дата-группа датафрейма заказов
datesGroups = orders[['date', 'group']].drop_duplicates()

#объявляю агрегированную переменную, содержащую число уникальных заказов в группе теста, число уникальных пользователей, 
#совершивших хотя бы 1 заказ в группе теста и суммарную выручку заказов в группе теста по указанную дату включительно
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
                                     .agg({'date': 'max', 'group': 'max', 'transactionId': pd.Series.nunique, 'visitorId': pd.Series.nunique, 'revenue': 'sum'}), axis = 1).sort_values(by = ['date', 'group'])

#объявляю агрегированную переменную с количеством уникальных посетителей в группе теста по указанную дату включительно 
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])]\
                                       .agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])


cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on = ['date', 'group'], right_on = ['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

cumulativeData.head()
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %%
#переменная с данными о датах, выручке и числе заказов в группе A
cumulativeRevenueA = cumulativeData[cumulativeData['group'] == 'A'][['date', 'revenue', 'orders']]

#переменная с данными о датах, выручке и числе заказов в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group'] == 'B'][['date', 'revenue', 'orders']]

#строю график кумулятивной выручки по группам
plt.figure(figsize=(15,5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label = 'A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label = 'B')
plt.legend()
plt.title('График кумулятивной выручки по группам', fontsize=15)
plt.ylabel('Кумулятивная выручка, руб', fontsize=12)
plt.xlabel('Дата', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label = 'A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label = 'B')
plt.title('График кумулятивной выручки по группам', fontsize=15)
plt.ylabel('Кумулятивная выручка, руб', fontsize=12)
plt.xlabel('Дата', fontsize=12)
plt.annotate('скачок', xy=('2019-08-17', 2800000), xytext=('2019-08-10', 3500000), arrowprops=dict(facecolor='g'))
plt.annotate('отрыв', xy=('2019-08-05', 800000), xytext=('2019-08-05', 2000000), arrowprops=dict(facecolor='g'))
plt.show()

# %% [markdown]
# В первые пять дней сегменты A и B идут вровень, с 5 августа B выходит вперед, 13 августа A показывает одинаковую кумулятивную выручку с B, но B с этого дня вырывается вперед уже до конца теста.
# Отмечу, что на протяжении теста выручки в обеих группах непрерывно растут, а в группе B наблюдается скачок 18 августа, что-то повлекло всплеск заказов.

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %%
#строю график кумулятивного среднего чека по группам, поделив выручку на кумулятивное число заказов 
plt.figure(figsize=(15,5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label = 'A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label = 'B')
plt.legend()
plt.title('График кумулятивного среднего чека по группам', fontsize=15)
plt.ylabel('Кумулятивный средний чек, руб', fontsize=12)
plt.xlabel('Дата', fontsize=12)
plt.show()

# %% [markdown]
# Средний чек растет непостоянно. До 15 августа группы A и B то и дело меняют свои позиции, но после уже замеченного ранее всплеска заказов 18 августа, группа B вырывается вперед уже до конца теста, правда после всплеска заказов средний чек имеет убывающий тренд

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A

# %%
#для построения гафика относительного изменения кумулятивного среднего чека группы B к группе A, объединяю таблицы кумулятивной прибыли для каждой группы
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on = 'date', right_on = 'date', how = 'left', suffixes = ['A', 'B'])

plt.figure(figsize=(15,5))
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB'] / mergedCumulativeRevenue['ordersB']) / (mergedCumulativeRevenue['revenueA'] / mergedCumulativeRevenue['ordersA']) -1)
plt.axhline(y=0, color='black', linestyle='--')
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A', fontsize=15)
plt.ylabel('Отношение среднего чека группы B к A', fontsize=12)
plt.xlabel('Дата', fontsize=12)
plt.show()

# %% [markdown]
# График отображает, как сильно менялся средний чек по результатам теста, можно увидеть сильные выбросы - даты крупных заказов

# %% [markdown]
# ### График кумулятивной конверсии по группам

# %%
#для построения графика кумулятивной конверсии добавляю в общий датафрейм столцец конверсии - отношение заказов к посетителям
cumulativeData['conversion'] = cumulativeData['orders'] / cumulativeData['visitors']
cumulativeDataA = cumulativeData[cumulativeData['group'] == 'A']
cumulativeDataB = cumulativeData[cumulativeData['group'] == 'B']

plt.figure(figsize=(15,5))
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label = 'A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label = 'B')
plt.legend()
plt.title('График кумулятивной конверсии по группам', fontsize=15)
plt.ylabel('Кумулятивная конверсия', fontsize=12)
plt.xlabel('Дата', fontsize=12)
plt.axis(["2019-08-01", '2019-09-01', 0.027, 0.038]) 
plt.show()

# %% [markdown]
# На графике кумулятивной конверсии видно, что до 6 августа конверсия групп не была постоянной, но с 6 августа конверсия группы B опередила группу A, и до конца теста сохранила свои позиции, зафиксировав показатель на уровне 0.033-0.035, тогда как у группы A конверсия тоже зафиксирвоалась, но на более низком уровне 0.029-0.031

# %% [markdown]
# ### График относительного изменения кумулятивной конверсии группы B к группе A.

# %%
#создаю общий датафрейм кумулятивной конверсии
mergedCumulativeConversions = cumulativeDataA[['date', 'conversion']].merge(cumulativeDataB[['date', 'conversion']], left_on = 'date', right_on = 'date', how = 'left', suffixes = ['A', 'B'])

plt.figure(figsize=(15,5))
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label = "Относительный прирост конверсии группы B относительно группы A")
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.2, color='grey', linestyle='--')
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A', fontsize=15)
plt.ylabel('Отношение кумулятивной конверсии группы B к A', fontsize=10)
plt.xlabel('Дата', fontsize=12)
plt.axis(["2019-08-01", '2019-09-01', -0.13, 0.26])
plt.legend = None
plt.show()

# %% [markdown]
# График отношения кумулятивной конверсии группы B к A показывает, что в начале теста кумулятивная конверсия B просела по отношению к группе A, но зато потом сохраняла рост

# %% [markdown]
# ### Точечный график количества заказов по пользователям

# %%
#создаю датафрейм с группировкой заказов по пользователям 
ordersByUsers = orders.drop(['group', 'revenue', 'date'], axis = 1).groupby('visitorId', as_index=False).agg({'transactionId': pd.Series.nunique})
ordersByUsers.columns = ['visitorId', 'orders']
ordersByUsers.sort_values(by = 'orders', ascending = False)
# Out:
#        visitorId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# ...          ...     ...
# 359   1484903144       1
# 360   1485964287       1
# 361   1494664757       1
# 362   1495112755       1
# 1030  4283872382       1
#
# [1031 rows x 2 columns]

# %%
plt.hist(ordersByUsers['orders'], bins = (10))
plt.title('Гистограмма количества заказов', fontsize=15)
plt.ylabel('Количество заказов, шт.', fontsize=12)
plt.xlabel('Объем заказа, ед.', fontsize=12)
plt.show()

# %%
x_values = pd.Series(range(0, len(ordersByUsers)))
plt.scatter(x_values, ordersByUsers['orders'])
plt.title('Точечный график количества заказов по пользователям', fontsize=15)
plt.ylabel('Количество заказов, шт', fontsize=12)
plt.show()

# %% [markdown]
# В основном пользователи совершают один заказ, часть пользователей совершает два заказа, больше - гораздо реже

# %% [markdown]
# ### 95-й и 99-й перцентили количества заказов на пользователя

# %%
print(np.percentile(ordersByUsers['orders'], [90, 95, 99]))
# Out:
# [1. 2. 4.]

# %% [markdown]
# 90% пользователей совершают не более 1 заказа. не более 5% пользователей делают второй заказ и только не более 1% - 4+ заказа.
# Все, что свыше 3 заказов, можно уже считать аномальным

# %% [markdown]
# ### Точечный график стоимостей заказов

# %%
x_values = pd.Series(range(0, len(orders['revenue'])))
plt.scatter(x_values, orders['revenue'])
plt.title('Гистограмма стоимости заказов', fontsize=15)
plt.ylabel('Стоимость заказа, руб', fontsize=12)
plt.show()

# %% [markdown]
# Основная масса заказов стоимостью не больше 100000руб, есть выборочные заказы порядка 200тыс и свыше 1.2млн, которые выглядят аномально на фоне общей массы

# %% [markdown]
# ### 95-й и 99-й перцентили стоимости заказов

# %%
print(np.percentile(orders['revenue'], [90, 95, 99]))
# Out:
# [18168.  28000.  58233.2]

# %% [markdown]
# Не более, чем у 5% пользователей средний чек больше 28000, и не более, чем у 1% - дороже 58тыс.
# 90% пользователей совершает заказы на сумму не больше 18168руб.
#
# Аномальной можно считать сумму заказа более 40тыс

# %% [markdown]
# ### Статистическая значимость различий в конверсии между группами по «сырым» данным

# %% [markdown]
# Рассчитаю статистическую значимость различий в конверсии между группами A и B по «сырым» данным и проверю гипотезы:
#
# H0 - нулевая гипотеза о том, что статистически значимых различий в конверсии между группами A и B нет
#
# H1 - альтернативная гипотеза о том, что есть статистические различия между конверсиями групп A и B
#
# Критический уровень статистической значимости 0.05, исходя из общепринятых пороговых значений

# %%
#число пользователей по дате в группе A
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

#количество пользователей до выбранной даты включительно в группе A
visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

#число пользователей по дате в группе B
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

#количество пользователей до выбранной даты включительно в группе B
visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']


ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

#число совершённых заказов для пользователей группы A, которые заказывали хотя бы 1 раз
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitorId', 'orders']

#число совершённых заказов для пользователей группы B, которые заказывали хотя бы 1 раз
ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitorId', 'orders']

#переменные для групп A и B, в которых пользователям с заказами соотвутствует число заказов пользователя. а пользователям без заказов — нули
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print("{0:.4f}".format(stats.mannwhitneyu(sampleA, sampleB, alternative='two-sided')[1]))
print("{0:.3f}".format((data['ordersPerDateB'].sum()/data['visitorsPerDateB'].sum())/(data['ordersPerDateA'].sum()/data['visitorsPerDateA'].sum())-1))
# Out:
# 0.0168
# 0.138

# %% [markdown]
# p-value  меньше 0.05 - стандартного общепринятого значения уровня значимости (у нас - 0.0168), поэтому нулевая гипотеза о том, что статистически значимых различий в конверсии между группами нет, отвергается.
#
# Анализ показывает, что в конверсии между группами есть статистически значимые различия. Относительный прирост конверсии группы B относительно группы A равен 13.8%

# %% [markdown]
# ### Статистическая значимость различий в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# Рассчитаю статистическую значимость различий в среднем чеке заказа между группами A и B по «сырым» данным и проверю гипотезы:
#
# H0 - нулевая гипотеза о том, что статистически значимых различий в среднем чеке заказа между группами A и B нет
#
# H1 - альтернативная гипотеза о том, что есть статистические различия между средними чеками заказа групп A и B
#
# Критический уровень статистической значимости 0.05, исходя из общепринятых пороговых значений

# %%
#относительные различия в среднем чеке между группами
print('{0:.3f}'.format(stats.mannwhitneyu(orders[orders['group'] == 'A']['revenue'], orders[orders['group'] == 'B']['revenue'], alternative='two-sided')[1]))
print('{0:.3f}'.format(orders[orders['group'] == 'B']['revenue'].mean()/orders[orders['group'] == 'A']['revenue'].mean()-1))
# Out:
# 0.729
# 0.259

# %% [markdown]
# p-value значительно больше 0.05 (0.729), значит, статистически значимых отличий в среднем чеке между группами нет, т.е. причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет.
#
# Относительное различие между средними чеками в группах составляет целых 25.9%

# %% [markdown]
# ### Статистическая значимость различий в конверсии между группами по «очищенным» данным

# %% [markdown]
# Рассчитаю статистическую значимость различий в конверсии между группами A и B по «очищенным» данным и проверю гипотезы:
#
# H0 - нулевая гипотеза о том, что статистически значимых различий в конверсии между группами A и B нет
#
# H1 - альтернативная гипотеза о том, что есть статистические различия между конверсиями групп A и B
#
# Критический уровень статистической значимости 0.05, исходя из общепринятых пороговых значений

# %%
#создаю срезы с аномальным числом заказов и трат (больше 3 заказов и сумма заказа свыше 40тыс)
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 3]['visitorId'],
        ordersByUsersB[ordersByUsersB['orders'] > 3]['visitorId'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > 40000]['visitorId']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
abnormalUsers.head(10)
# Out:
# 1099    148427295
# 18      199603092
# 23      237748145
# 684     358944393
# 648     382846391
# 1137    759473111
# 339     834731816
# 949     887908475
# 744     888512513
# 709     950626008
# Name: visitorId, dtype: int64

# %%
abnormalUsers.count()
# Out:
# 34

# %% [markdown]
# Всего 34 пользователя с аномальным поведением

# %%
# создаю переменные с очищенными данными о заказах (без аномалий)
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitorId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitorId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print('{0:.4f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered, alternative='two-sided')[1]))
print('{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# 0.0093
# 0.164

# %% [markdown]
# Подтверждаются значения, полученные с сырыми данными:
#
# p-value меньше 0.05 - стандартного общепринятого значения уровня значимости (у нас - 0.0093), поэтому нулевая гипотеза о том, что статистически значимых различий в конверсии между группами нет, отвергается.
#
# Анализ показывает, что в конверсии между группами есть статистически значимые различия. Относительный прирост конверсии группы B относительно группы A равен 16.4%, сегмент B превосходит сегмент A

# %% [markdown]
# ### Статистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# Рассчитаю статистическую значимость различий в среднем чеке заказа между группами A и B по «очищенным» данным и проверю гипотезы:
#
# H0 - нулевая гипотеза о том, что статистически значимых различий в среднем чеке заказа между группами A и B нет
#
# H1 - альтернативная гипотеза о том, что есть статистические различия между средними чеками заказа групп A и B
#
# Критический уровень статистической значимости 0.05, исходя из общепринятых пороговых значений

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        alternative='two-sided')[1], 
    )
)

print(
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.711
# 0.060

# %% [markdown]
# p-value увеличился и он все так же больше 0.05 - стандартного общепринятого значения уровня значимости. Появилась статистическая значимость различия среднего чека заказов между группами. После очистки от аномалий в данных стало меньше шума.
# Разница между сегментами была почти 26%, а сократилась до 6%, после удаления аномалий

# %% [markdown]
# ## Вывод, результаты A/B теста

# %% [markdown]
# <b>Результаты A/B теста:</b>
#
# Есть статистически значимое различие по конверсии между группами как по сырым данным, так и после фильтрации аномалий. (Группа B превосходит группу A)
#
# По сырым данным нет статистически значимого различия по среднему чеку между группами по сырым данным и очищенным.
#
# График различия конверсии между группами сообщает, что результаты группы B лучше группы A: имеют тенденцию к росту, либо зафиксировались около среднего значения.
#
# График различия среднего чека колебался в начале теста, но после всплеска заказов 18 августа, группа B вырывается вперед уже до конца теста, правда после всплеска заказов средний чек имеет убывающий тренд
#
# <b>Итог: Остановить тест, зафиксировать победу группы B </b>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Из подготовленного списка гипотез для увеличения выручки интернет-магазина фреймворками ICE & RICE была произведена приоритизация, в результате которой было выделено две гипотезы: "Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей" и "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок".
# 2. Была проведена предобработка данных исходных датафреймов с заказами и посетителями интернет-магазина, разделенных на группы A и B, в ходе которой был изменен тип данных для столбцов, содержащих информацию о датах заказа, а также было обнаружено, что есть 58 пользователей, которые были вовлечены в обе группы тестирования.
# 3. В результате анализа данных по группам было отмечено:
#     - на протяжении теста выручки в обеих группах непрерывно растут, в первые пять дней сегменты A и B идут вровень, с 5 августа B выходит вперед, 13 августа A показывает одинаковую кумулятивную выручку с B, но B с этого дня вырывается вперед уже до конца теста;
#     - средний чек растет непостоянно. До 15 августа группы A и B то и дело меняют свои позиции, но после уже замеченного ранее всплеска заказов 18 августа, группа B вырывается вперед уже до конца теста, правда после всплеска заказов средний чек имеет убывающий тренд;
#     - при исследовании кумулятивной конверсии отмечено, что до 6 августа конверсия групп не была постоянной, но с 6 августа конверсия группы B опередила группу A, и до конца теста сохранила свои позиции, зафиксировав показатель на уровне 0.033-0.035, тогда как у группы A конверсия тоже зафиксировалась, но на более низком уровне 0.029-0.031;
#     - 90% пользователей совершают не более 1 заказа. не более 5% пользователей делают второй заказ и только не более 1% - 4+ заказа. при дальнейшем анализе было принято решение считать аномальным количество заказов свыше 3
#     - не более, чем у 5% пользователей средний чек больше 28000, и не более, чем у 1% - дороже 58тыс. 90% пользователей совершает заказы на сумму не больше 18168руб, было принято решение считать сумму заказа свыше 40000 руб аномальной;
# 4. Была рассчитана статистическая значимость различий в конверсии и среднем чеке заказа между группами A и B по «сырым» и по «очищенным» данным:
#     - отмечено статистически значимое различие по конверсии между группами как по сырым данным, так и после фильтрации аномалий. (Группа B превосходит группу A)
#     - по сырым данным нет статистически значимого различия по среднему чеку между группами, также как и по очищенным.
#
# 5. Исходя из вышеописанного, было принято решение Остановить тест, зафиксировав победу группы B

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - [x]  Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - [x]  Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.
# - [x]  Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# - [x]  Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# - [x]  Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# - [x]  Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# - [x]  Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# - [x]  Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# - [x]  Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# - [x]  Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# - [x]  Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# - [x]  Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# - [x]  Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# - [x]  Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# - [x]  Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# - [x]  Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.
